# %%
import pandas as pd
import numpy as np

# %%
gold_path = "/global/cfs/cdirs/des/zhou/image_simulation/data/gold_df.pkl"

# %%
gold = pd.read_pickle(gold_path)

# %%
gold_downsampled = gold.sample(frac=0.1)
